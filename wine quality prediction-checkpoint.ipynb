# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
#loading data
wines_df = pd.read_csv("wineQualityReds.csv")
wines_df.sample(frac = 1).reset_index(drop = True)
wines_df.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
display(wines_df.isna().sum())
# Out:
# fixed.acidity           0
# volatile.acidity        0
# citric.acid             0
# residual.sugar          0
# chlorides               0
# free.sulfur.dioxide     0
# total.sulfur.dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#plotting heatmap
correlation = wines_df.corr()

fig = plt.subplots(figsize=(10,10))
sns.heatmap(correlation,vmax=1,square=True,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
wines_df_before = wines_df
wines_df_after = wines_df.drop(['fixed.acidity','citric.acid','density'], axis = 1)

X1 = sm.tools.add_constant(wines_df_before)
X2 = sm.tools.add_constant(wines_df_after)

series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index=X1.columns)
series_after = pd.Series([variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])], index=X2.columns)

display(series_before)
display(series_after)

wines_df = wines_df_after
# Out:
# const                   1.711696e+06
# fixed.acidity           7.772051e+00
# volatile.acidity        1.879663e+00
# citric.acid             3.131055e+00
# residual.sugar          1.703859e+00
# chlorides               1.500591e+00
# free.sulfur.dioxide     1.968010e+00
# total.sulfur.dioxide    2.214467e+00
# density                 6.346491e+00
# pH                      3.339511e+00
# sulphates               1.487286e+00
# alcohol                 3.238899e+00
# quality                 1.563848e+00
# dtype: float64
# const                   672.114828
# volatile.acidity          1.321382
# residual.sugar            1.073584
# chlorides                 1.360177
# free.sulfur.dioxide       1.901710
# total.sulfur.dioxide      1.999505
# pH                        1.280173
# sulphates                 1.379674
# alcohol                   1.463216
# quality                   1.561599
# dtype: float64

# %%
x = np.array(wines_df.loc[:, wines_df.columns != 'quality'])
y = np.array(wines_df['quality'])

# %%
x
# Out:
# array([[ 0.7  ,  1.9  ,  0.076, ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 0.88 ,  2.6  ,  0.098, ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 0.76 ,  2.3  ,  0.092, ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 0.51 ,  2.3  ,  0.076, ...,  3.42 ,  0.75 , 11.   ],
#        [ 0.645,  2.   ,  0.075, ...,  3.57 ,  0.71 , 10.2  ],
#        [ 0.31 ,  3.6  ,  0.067, ...,  3.39 ,  0.66 , 11.   ]])

# %%
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6], dtype=int64)

# %%
desc_df = wines_df.describe()

desc_df.loc['+3_std'] = desc_df.loc['mean'] + (desc_df.loc['std'] * 3)
desc_df.loc['-3_std'] = desc_df.loc['mean'] - (desc_df.loc['std'] * 3)

desc_df
# Out:
#         volatile.acidity  residual.sugar    chlorides  free.sulfur.dioxide  \
# count        1599.000000     1599.000000  1599.000000          1599.000000
# mean            0.527821        2.538806     0.087467            15.874922
# std             0.179060        1.409928     0.047065            10.460157
# min             0.120000        0.900000     0.012000             1.000000
# 25%             0.390000        1.900000     0.070000             7.000000
# 50%             0.520000        2.200000     0.079000            14.000000
# 75%             0.640000        2.600000     0.090000            21.000000
# max             1.580000       15.500000     0.611000            72.000000
# +3_std          1.065000        6.768590     0.228662            47.255393
# -3_std         -0.009359       -1.690979    -0.053729           -15.505549
#
#         total.sulfur.dioxide           pH    sulphates      alcohol  \
# count            1599.000000  1599.000000  1599.000000  1599.000000
# mean               46.467792     3.311113     0.658149    10.422983
# std                32.895324     0.154386     0.169507     1.065668
# min                 6.000000     2.740000     0.330000     8.400000
# 25%                22.000000     3.210000     0.550000     9.500000
# 50%                38.000000     3.310000     0.620000    10.200000
# 75%                62.000000     3.400000     0.730000    11.100000
# max               289.000000     4.010000     2.000000    14.900000
# +3_std            145.153766     3.774273     1.166670    13.619986
# -3_std            -52.218181     2.847954     0.149628     7.225980
#
#             quality
# count   1599.000000
# mean       5.636023
# std        0.807569
# min        3.000000
# 25%        5.000000
# 50%        6.000000
# 75%        6.000000
# max        8.000000
# +3_std     8.058731
# -3_std     3.213314

# %%
X1
# Out:
#       const  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0       1.0            7.4             0.700         0.00             1.9
# 1       1.0            7.8             0.880         0.00             2.6
# 2       1.0            7.8             0.760         0.04             2.3
# 3       1.0           11.2             0.280         0.56             1.9
# 4       1.0            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1594    1.0            6.2             0.600         0.08             2.0
# 1595    1.0            5.9             0.550         0.10             2.2
# 1596    1.0            6.3             0.510         0.13             2.3
# 1597    1.0            5.9             0.645         0.12             2.0
# 1598    1.0            6.0             0.310         0.47             3.6
#
#       chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0         0.076                 11.0                  34.0  0.99780  3.51
# 1         0.098                 25.0                  67.0  0.99680  3.20
# 2         0.092                 15.0                  54.0  0.99700  3.26
# 3         0.075                 17.0                  60.0  0.99800  3.16
# 4         0.076                 11.0                  34.0  0.99780  3.51
# ...         ...                  ...                   ...      ...   ...
# 1594      0.090                 32.0                  44.0  0.99490  3.45
# 1595      0.062                 39.0                  51.0  0.99512  3.52
# 1596      0.076                 29.0                  40.0  0.99574  3.42
# 1597      0.075                 32.0                  44.0  0.99547  3.57
# 1598      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.56      9.4        5
# 1          0.68      9.8        5
# 2          0.65      9.8        5
# 3          0.58      9.8        6
# 4          0.56      9.4        5
# ...         ...      ...      ...
# 1594       0.58     10.5        5
# 1595       0.76     11.2        6
# 1596       0.75     11.0        6
# 1597       0.71     10.2        5
# 1598       0.66     11.0        6
#
# [1599 rows x 13 columns]

# %%
X2
# Out:
#       const  volatile.acidity  residual.sugar  chlorides  free.sulfur.dioxide  \
# 0       1.0             0.700             1.9      0.076                 11.0
# 1       1.0             0.880             2.6      0.098                 25.0
# 2       1.0             0.760             2.3      0.092                 15.0
# 3       1.0             0.280             1.9      0.075                 17.0
# 4       1.0             0.700             1.9      0.076                 11.0
# ...     ...               ...             ...        ...                  ...
# 1594    1.0             0.600             2.0      0.090                 32.0
# 1595    1.0             0.550             2.2      0.062                 39.0
# 1596    1.0             0.510             2.3      0.076                 29.0
# 1597    1.0             0.645             2.0      0.075                 32.0
# 1598    1.0             0.310             3.6      0.067                 18.0
#
#       total.sulfur.dioxide    pH  sulphates  alcohol  quality
# 0                     34.0  3.51       0.56      9.4        5
# 1                     67.0  3.20       0.68      9.8        5
# 2                     54.0  3.26       0.65      9.8        5
# 3                     60.0  3.16       0.58      9.8        6
# 4                     34.0  3.51       0.56      9.4        5
# ...                    ...   ...        ...      ...      ...
# 1594                  44.0  3.45       0.58     10.5        5
# 1595                  51.0  3.52       0.76     11.2        6
# 1596                  40.0  3.42       0.75     11.0        6
# 1597                  44.0  3.57       0.71     10.2        5
# 1598                  42.0  3.39       0.66     11.0        6
#
# [1599 rows x 10 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=1)

print(x_train.shape, x_test.shape)
# Out:
# (1439, 8) (160, 8)

# %%
#linear regression
regression_model = LinearRegression()

regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = regression_model.predict(x_test)
y_predict = np.round(y_predict)

sum = 0
for i,n in enumerate(y_test):
    if n == y_predict[i]:
        sum += 1
print(sum/len(y_test))
# Out:
# 0.71875

# %%
y_predict
# Out:
# array([6., 5., 6., 6., 7., 6., 6., 5., 6., 5., 6., 5., 6., 6., 6., 5., 6.,
#        5., 6., 5., 6., 6., 5., 6., 5., 6., 6., 6., 5., 6., 5., 6., 5., 6.,
#        5., 6., 5., 5., 6., 5., 6., 5., 5., 6., 5., 6., 5., 5., 5., 6., 6.,
#        5., 6., 5., 5., 6., 6., 6., 6., 5., 6., 5., 5., 6., 5., 5., 7., 6.,
#        6., 6., 5., 6., 6., 6., 5., 5., 6., 5., 6., 6., 6., 5., 5., 6., 6.,
#        5., 5., 6., 5., 6., 5., 6., 5., 6., 6., 5., 6., 5., 5., 6., 5., 5.,
#        5., 5., 5., 5., 6., 5., 6., 6., 6., 5., 6., 5., 5., 7., 5., 5., 5.,
#        5., 5., 7., 6., 5., 5., 5., 6., 5., 6., 6., 6., 5., 6., 5., 6., 6.,
#        5., 6., 5., 5., 5., 5., 6., 5., 6., 6., 6., 5., 6., 6., 6., 6., 5.,
#        5., 6., 6., 6., 6., 6., 5.])
